# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!
#
# *Notes:*
#
# - Solve the questions with python.
#
# - Round the final answer to three decimal places.

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12,8)
import math

# %% [markdown]
# ## Bernoulli's Distribution
#
# In a basket containing 100 fruits, there are 60 apples and 40 oranges.
#
# A fruit is picked randomly from the basket.
#
# 1. **What is the probability that the fruit is apple?**
# 1. **What is the probability that it is an orange?**

# %%
"""
Calculate:
p = probability that the fruit is an apple 
q = probability that the fruit is an orange
"""

# your code here
x = 100
p = 60/100
q = 40/100

print(f'The probability that the fruit is an apple is {round(p,3)}, and the probability of being an orange is {round(q,3)}')
# Out:
# The probability that the fruit is an apple is 0.6, and the probability of being an orange is 0.4

# %% [markdown]
# Now we take a random sample of 20 fruits from the basket. After each fruit is taken, a new fruit of the same type is replaced in the basket. Therefore, every time we are taking 1 fruit from 100 fruits.
#
# 1. **What is the probability that the first 5 fruits are all apples?**
#
# 1. **What is the probability that the first 5 fruits are all apples and the next 15 fruits are all oranges?**
#
# You can include the `p` and `q` probabilities you previous calculated in your solution.

# %%
# your code here
# 1. What is the probability that the first 5 fruits are all apples?
all_apples = stats.binom(5,p).pmf(5)

print(f'The probability that the first 5 fruits are all apples is {round(all_apples, 3)}')

# 2. What is the probability that the first 5 fruits are all apples and the next 15 fruits are all oranges?
apples_and_oranges = stats.binom(5,p).pmf(5) * stats.binom(15,q).pmf(15)

print(f'The probability that the first 5 fruits are all apples and the next 15 fruits are all oranges is {round(apples_and_oranges, 3)}')
# Out:
# The probability that the first 5 fruits are all apples is 0.078
# The probability that the first 5 fruits are all apples and the next 15 fruits are all oranges is 0.0

# %% [markdown]
# ## Binomial Distribution
#
# Similar to the above problem, this time again we randomly sample 20 fruits.
#
# **What is the probability that this time the sample contains 5 apples and 15 oranges?**
#
# Please note that this time the order of the fruits being picked does not matter.

# %%
# your code here
p5_apples = stats.binom(20,p).pmf(5)
p15_oranges = stats.binom(20,q).pmf(15)
p5_apples == p15_oranges

print(f'The probability that this time the sample contains 5 apples and 15 oranges is {round(p5_apples, 3)}')
# Out:
# The probability that this time the sample contains 5 apples and 15 oranges is 0.001

# %% [markdown]
# In the lesson we also discussed CDF (cumulative distribution function). In the context of the above problem, **what is the probability that less than 5 fruits picked are apples?**
#
# Write the formula and calculate the probability below.

# %%
# your code here
p_less_5apples = stats.binom(20,p).cdf(5)

print(f'The probability that less than 5 fruits picked are apples is {round(p_less_5apples, 3)}')
# Out:
# The probability that less than 5 fruits picked are apples is 0.002

# %% [markdown]
# **Plot the PDF (probability distributiom function) for the above binomial distribution.**
#
# *Hint: The range of x in a binomial distribution is from `0` to `n`.*

# %%
# your code here
# Please label the axes and give a title to the plot 

n = 20
p = 0.6
binomial = stats.binom(n, p)
x = np.arange(0, n+1)
fmp = binomial.pmf(x) # Probability Mass Function
plt.plot(x, fmp) 
plt.vlines(x, ymin=0, ymax=fmp, linestyles='dotted')
plt.title('Probability Distribution Function (PDF)')
plt.xlabel('Apples')
_ = plt.ylabel('Probability')

# %% [markdown]
# ## Poisson Distribution
#
# In this challenge you are required to use the Math library in python to solve the problems.
#
# In the UEFA champions league tournament, the average number of goals scored in a match is 2.3.
#
# **What is the probability that the number of goals scored in a match is 5?**
#
# *Hint: Use the exp() in the math library*
#
# And to calculate the factorial, you can use the following code:
#
# ```python
# import math
# math.factorial(n) # n is the number you want to find the factorial of
# ```

# %%
# your code here 
p_goals = stats.poisson(2.3).pmf(5)

print(f'The probability that the number of goals scored in a match is 5 is {round(p_goals, 3)}')
# Out:
# The probability that the number of goals scored in a match is 5 is 0.054

# %% [markdown]
# **Draw a poisson probability distribution plot for the number of goals to be between 0 to 10.**

# %%
# your code here
# Please label the axes and give a title to the plot 

mu = 2.3
poisson = stats.poisson(mu)
x = np.arange(0, 11)
fmp = poisson.pmf(x) 
plt.plot(x, fmp)
plt.vlines(x, ymin=0, ymax=fmp, linestyles='dotted')
plt.title('Poisson Probability Distribution')
plt.xlabel('Goals')
_ = plt.ylabel('Probability')
